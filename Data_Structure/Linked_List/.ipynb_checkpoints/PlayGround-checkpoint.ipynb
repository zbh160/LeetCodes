# %%
# Logic 
# Find the Last node or the node specified to terminate the loop
# Do logic of data change
# Return value
# e.g. list 1 2 3 4 5 6 m = 2, n = 5 1 -> 2 m =1 n =4, rev(2, 4) -> successor = 6, last = 5, 5->4 -> 4->3 -> 3->2 -> 2->6

# %%
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
successor = None # successor node
class Solution(object):
    def reverseList(self, head):
        """
        :type head: ListNode
        :rtype: ListNode
        """
        if head is None or head.next == None:
            return head
        last = self.reverseList(head.next)
        head.next.next = head
        head.next = None 
        return last

    # reverse n nodes starting from head, and return new head
    def reverseN(self, head, n):
        global successor
        if (n == 1):  
            # mark the (n + 1)th node
            successor = head.next
            print(head.data,head.next.data,n)
            return head

        # starts from head.next, revers the first n - 1 nodes
        last = self.reverseN(head.next, n - 1)

        head.next.next = head
        # link the new head to successor
        head.next = successor
        return last
    # reverse n nodes tarting from m, and return new head, index start from 1
    def reverseBetween(self, head, m,  n): 
        #  base case
        if (m == 1):
            print(head.data, n)
            return self.reverseN(head, n)
    
        head.next = self.reverseBetween(head.next, m - 1, n - 1)
        return head
    # Simple Reverse Recursion Practise 
    def after_recursion_explore(self, head):
        # Modify each node by adding value of next node
        if head is None or head.next is None:
            return
        '''
                # Display current node
        # print(head.data)
        # stop to get the last element of Linked_List
        # if head is None or head.next == None:
        # test using 3 as stop condition
        # Find Middle Element
        slow = head
        fast = head
        while fast is not None and fast.next is not None:
            fast = fast.next.next
            slow = slow.next
        
        # Handle Odd if no. of nodes are odd then move slow to one point
        if fast is not None and fast.next is not None:
            slow = slow.next
    
        # Reverse middle end part
        prev = None
        temp = None
            
        while slow is not None and slow.next is not None:
            temp = slow.next
            slow.next = prev
            prev = slow
            slow = temp

        if slow is not None:
            slow.next = prev
        
        # Compare
        fast = head
        while slow and fast:
            if slow.data != fast.data:
                return False
            slow = slow.next
            fast = fast.next
        return True
        '''
        
        '''
        
        if head.data == 3:
            head.data = "test" + str(head.data)
            return head
        # recuring 
        last = self.after_recursion_explore(head.next)
        
        # Operating starting from the last element
        # Example, change value to 1 and reverse
        # head.next.next = head
        # head.next = None
        head.data = "test" + str(head.data)
        # print(last.data)
        print(head.data)
        return head
        # return last
        
        1 -> 2 -> 3
        temp = None
        prev = None
        temp = slow.next = 2
        slow.next = prev = None
        prev = slow = 1
        slow = temp = 2
        
        
            while slow is not None and slow.next is not None:
                temp = slow.next
                slow.next = prev
                prev = slow
                slow = temp
        '''
    def intersect_two_practice(self, head1, head2):
        l1 = head1
        l2 = head2
        # Loop exit only when l1 = l2
        i = 0
        print("Start Node: ")
        print(l1.data)
        print(l2.data)
        while (l1 != l2):
            i += 1
            print("Step %i"%i)
            print("New Node:")
            if l1 is None or l1.next is None:
                l1 = head2
                print("end of l1: %s"%l1.data)
            else:
                l1 = l1.next
                print(l1.data)
            if l2 is None or l2.next is None:
                l2 = head1
                print("end of l2: %s"%l2.data)
            else:         
                l2 = l2.next
                print(l2.data)
        if l1 is not None:
            print("%i Steps taken, intersection found: %s"%(i,l1.data))
        else:
            print("%i Steps taken, no intersection found"%i)

        return l1

# %%
class ListNode:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

# Create nodes
node1 = ListNode(1)
node2 = ListNode(2)
node3 = ListNode(3)
node4 = ListNode(4)
node5 = ListNode(5)
node6 = ListNode(6)

# Link nodes
node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5
node5.next = node6

# Create a linked list
linked_list = LinkedList()
linked_list.head = node1

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, x, tag):
        self.data = x
        self.next = None
        self.tag = tag

class LinkedList:
    def __init__(self):
        self.head = None

# Create nodes


lista_node1 = ListNode("a1", "l1")
lista_node2 = ListNode("a2", "l1")

listb_node1 = ListNode("b1", "l2")
listb_node2 = ListNode("b2", "l2")
listb_node3 = ListNode("b3", "l2")



listc_node1 = ListNode("c1", "l1")
listc_node2 = ListNode("c2", "l1")
listc_node3 = ListNode("c3", "l1")


# Link nodes
lista_node1.next = lista_node2
lista_node2.next = listc_node1

listb_node1.next = listb_node2
listb_node2.next = listb_node3
listb_node3.next = listc_node1

listc_node1.next = listc_node2
listc_node2.next = listc_node3

# Create a linked list
linked_lista = LinkedList()
linked_listb = LinkedList()
linked_lista.head = lista_node1
linked_listb.head = listb_node1

# %%
solution = Solution()

# %%
# Draw Inference, reverse first M - N element
# worked!
# result = solution.reverseList(node1)
# worked!
# result = solution.reverseN(node1,3)
# worked!
# result =  solution.after_recursion_explore(node1)
# result =  solution.after_recursion_explore(node1)
result = solution.intersect_two_practice(lista_node1, listb_node1)
# Out:
# Step 1
# New Node:
# a2
# c1
# Step 2
# New Node:
# c1
# c2
# Step 3
# New Node:
# c2
# c3
# Step 4
# New Node:
# c3
# end of l2: a1
# Step 5
# New Node:
# end of l1: a2
# a2
# 5 Steps taken, intersection found: a2

# %%
# Display result
'''
while result.data != None:
    print(result.data)
    if result.next !=None:
        result = result.next
    else:
        break
'''
print(result.data)
# Out:
# a2
